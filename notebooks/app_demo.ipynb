# %%
from tempods.app import TempoApp

app = TempoApp()
app

# %%
import solara

# %%
from tempods.solara_app import Page

# %%
Page()
# Out:
# Rendering Page
# ['ipyvolume:lasso', 'ipyvolume:circle', 'ipyvolume:rectangle']
# Initializing IpyLeafletMapViewer...
# Creating data layer artist for <glue_map.data.RemoteGeoData_ArcGISImageServer object at 0x308ce9990> with class MapImageServerLayerArtist
# Calling update_profile...
# Getting temporal data for TEMPO_NO2_L3_V03_HOURLY_TROPOSPHERIC_VERTICAL_COLUMN from 2024-10-15 00:00:00 to 2024-10-16 00:00:00
# Calling update_profile...
# done updating profile cache...
# Calling update_profile...
# Rendering Page
# Initializing IpyLeafletMapViewer...
# Creating data layer artist for <glue_map.data.RemoteGeoData_ArcGISImageServer object at 0x310c635d0> with class MapImageServerLayerArtist
# Calling update_profile...
# Getting temporal data for TEMPO_NO2_L3_V03_HOURLY_TROPOSPHERIC_VERTICAL_COLUMN from 2024-10-15 00:00:00 to 2024-10-16 00:00:00
# Calling update_profile...
# done updating profile cache...
# Calling update_profile...
# Cannot show ipywidgets in text
